# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravani-111/Fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 17:48:51--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   170MB/s    in 0.4s
#
# 2024-03-30 17:48:54 (170 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11230  1504.07235v1  We study the use of "sign $\alpha$-stable rand...  stat
# 13701   1211.1119v1  In the field of empirical modeling using Genet...    cs
# 22028   1312.3291v1  The detection of anomalous activity in graphs ...  stat
# 31911   1208.2112v2  We present new algorithms for inverse reinforc...    cs
# 6046   1606.05060v1  We propose to prune a random forest (RF) for r...  stat
# ...             ...                                                ...   ...
# 8906   1703.00948v1  In this work, we open up the DAWT dataset - De...    cs
# 36791   1411.6754v1  Nowadays, online clothes-selling business has ...    cs
# 5908    1212.6246v1  Gaussian Process (GP) regression models typica...  stat
# 12411  1801.05852v1  With the widespread use of information technol...    cs
# 12209  1710.06570v1  A number of recent papers have provided eviden...  stat
#
#                                                    title  year  \
# 11230  Sign Stable Random Projections for Large-Scale...  2015
# 13701  A Survey on Techniques of Improving Generaliza...  2012
# 22028  Near-optimal Anomaly Detection in Graphs using...  2013
# 31911  Inverse Reinforcement Learning with Gaussian P...  2012
# 6046   Pruning Random Forests for Prediction on a Budget  2016
# ...                                                  ...   ...
# 8906   DAWT: Densely Annotated Wikipedia Texts across...  2017
# 36791  HCRS: A hybrid clothes recommender system base...  2014
# 5908   Gaussian Process Regression with Heteroscedast...  2012
# 12411          Network Representation Learning: A Survey  2017
# 12209  A Correspondence Between Random Neural Network...  2017
#
#                                                 keywords
# 11230  [projections, processing, applications, classi...
# 13701  [empirical, programming, important, generaliza...
# 22028  [detection, anomalous, statistical, applicatio...
# 31911  [algorithms, reinforcement, optimization, quad...
# 6046   [constrained, prediction, construct, constrain...
# ...                                                  ...
# 8906   [annotated, wikipedia, languages, annotations,...
# 36791  [extremely, attractive, convenience, successfu...
# 5908   [regression, typically, residuals, observation...
# 12411  [widespread, information, technologies, inform...
# 12209  [practical, questions, theoretically, availabl...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11230    [projections, processing, applications, classi...
# 13701    [empirical, programming, important, generaliza...
# 22028    [detection, anomalous, statistical, applicatio...
# 31911    [algorithms, reinforcement, optimization, quad...
# 6046     [constrained, prediction, construct, constrain...
#                                ...
# 11579    [automated, discovery, challenge, addressing, ...
# 30863    [recognition, knowledge, convolutional, archit...
# 13256    [computational, technique, artificial, automat...
# 15734    [challenges, advantages, coreference, resoluti...
# 13345    [alternatives, resolution, diagnosis, knowledg...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8859 words.
# Out of those 4593 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4762f6d1-0d80-4b9d-94a6-07dac0d5d8c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4762f6d1-0d80-4b9d-94a6-07dac0d5d8c3")) {                    Plotly.newPlot(                        "4762f6d1-0d80-4b9d-94a6-07dac0d5d8c3",                        [{"x":["extensive","effectiveness","applications","especially","classification","resemblance","processing","processed","practitioners","empirical","approximating","perspective","parameter","literature","algorithms","corresponds","projections","particular","essentially","procedure","clustering","regression","approximates","effective","consistent","depending","nonlinear","approximate","corresponding","solutions","selecting","discussed","important","classified","understand","limitation","generalization","improving","approaches","different","following","community","comparing","techniques","appropriate","programming","inference","principles","balancing","difficulty","detection","applicability","intractable","connected","likelihood","structured","computationally","activation","performance","algorithm","electrical","generalized","anomalous","relaxation","complexity","infeasible","conditions","statistic","demonstrate","surveillance","posteriori","submodularity","statistical","connection","monitoring","computational","determining","numerical","observations","apprenticeship","comparison","trajectories","posterior","represent","reinforcement","potential","distinguished","implementations","manageable","optimization","objective","quadratic","estimation","demonstrated","framework","dependence","establish","preference","assumptions","generally","initialization","heuristics","encourages","outperforms","acquiring","combinatorial","construct","efficient","constraint","connections","prediction","constrained","conventional","constraints","requiring","empirically","expressive","assignments","exponential","establishing","encodings","polynomial","functions","preliminary","regarding","variables","characterization","propositional","satisfiability","computable","resolution","addresses","convolutional","interesting","representation","benchmarks","developing","capability","structure","configurations","automatically","classical","convolution","discriminative","properties","classifiers","facilitates","contextual","iterative","approximation","accomplish","structural","specification","sequential","capitalizes","institutional","resonance","similarity","segmented","automatic","performed","consuming","architecture","measurements","complimentary","validation","experiments","architectures","osteoporosis","segmentation","exceeding","precision","segmentations","management","volumetric","factorization","recommender","knowledge","extracted","technique","extracting","extraction","incorporate","illustrate","recommendation","available","interactions","expressed","predicted","analyzing","challenging","employing","incorporating","hellinger","relations","explicitly","describing","increasingly","information","experimental"],"y":[175,203,405,124,512,2,279,24,17,159,11,68,122,127,610,23,20,261,25,107,161,102,8,236,69,26,59,108,139,153,45,68,359,29,71,21,123,105,443,742,69,78,74,376,94,127,215,34,8,51,344,39,20,69,66,103,101,44,915,810,6,78,6,20,230,6,129,5,529,29,10,4,160,36,30,308,39,87,79,2,133,21,31,117,114,151,6,46,2,314,157,30,216,109,549,25,50,24,57,62,34,42,8,263,6,38,69,399,102,55,236,60,110,148,55,63,34,14,48,10,9,74,230,50,48,121,27,20,14,8,129,50,382,85,380,105,70,52,333,28,168,109,44,88,187,130,13,51,84,110,11,77,17,60,2,2,28,152,30,196,125,44,262,59,3,38,604,143,3,204,6,90,16,52,14,38,14,358,108,252,61,119,47,65,24,287,72,38,54,64,263,33,55,3,93,72,34,53,658,361],"type":"bar"},{"x":["extensive","effectiveness", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4593,), (4593, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>PronouncUR</span> <span style=''>An</span> <span style=''>Urdu</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Pronunciation</span> <span style=''>Lexicon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generator</span> <br/><br/><span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.6589473684210525);'>recognition</span> <span style=''>systems</span> <span style=''>rely</span> <span style=''>heavily</span> <span style=''>on</span> <span style=''>three</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>an</span> <span style=''>acoustic</span> <span style=''>model</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>pronunciation</span> <span style=''>lexicon</span> <span style=''>and</span> <span style=''>a</span> <span style=''>language</span> <span style=''>model</span> <span style=''>To</span> <span style=''>build</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>researcher</span> <span style=''>needs</span> <span style='background-color:rgba(0, 255, 0, 0.9500000000000001);'>linguistic</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3134328358208955);'>technical</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529411);'>expertise</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>barrier</span> <span style=''>in</span> <span style=''>low</span> <span style=''>resource</span> <span style=''>domains</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Techniques</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>these</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>without</span> <span style=''>having</span> <span style=''>expert</span> <span style=''>domain</span> <span style='background-color:rgba(0, 255, 0, 0.4206349206349206);'>knowledge</span> <span style=''>are</span> <span style=''>in</span> <span style=''>great</span> <span style=''>demand</span> <span style=''>Urdu</span> <span style=''>despite</span> <span style=''>having</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>speakers</span> <span style=''>all</span> <span style=''>over</span> <span style=''>the</span> <span style=''>world</span> <span style=''>is</span> <span style=''>a</span> <span style=''>low</span> <span style=''>resource</span> <span style=''>language</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>publically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style='background-color:rgba(0, 255, 0, 0.9500000000000001);'>linguistic</span> <span style='background-color:rgba(0, 255, 0, 0.6326530612244898);'>resources</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>grapheme</span> <span style=''>to</span> <span style=''>phoneme</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521735);'>conversion</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>Urdu</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157895);'>generates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>pronunciation</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>datasets</span> <span style=''>by</span> <span style=''>a</span> <span style=''>minimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Analyzing</span> <span style=''>large</span> <span style=''>volumes</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>is</span> <span style=''>an</span> <span style=''>issue</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>in</span> <span style=''>data</span> <span style=''>science</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>molecular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>and</span> <span style=''>beyond</span> <span style=''>Several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>work</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>content</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>belongs</span> <span style=''>to</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimension</span> <span style=''>(ID)</span> <span style=''>is</span> <span style=''>much</span> <span style=''>lower</span> <span style=''>than</span> <span style=''>the</span> <span style=''>crude</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>Such</span> <span style=''>manifold</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>twisted</span> <span style=''>and</span> <span style=''>curved</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>points</span> <span style=''>on</span> <span style=''>it</span> <span style=''>will</span> <span style=''>be</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniformly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>two</span> <span style=''>factors</span> <span style=''>that</span> <span style=''>make</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ID</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>really</span> <span style=''>hard</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>ID</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>using</span> <span style=''>only</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>and</span> <span style=''>the</span> <span style=''>second</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>from</span> <span style=''>Pairwise</span> <span style=''>Marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Independencies</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>graphs</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represent</span> <span style=''>pairwise</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independencies</span> <span style=''>amongst</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3965087281795512);'>variables</span> <span style=''>(for</span> <span style=''>instance</span> <span style=''>the</span> <span style=''>zero</span> <span style=''>entries</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.712);'>covariance</span> <span style=''>matrix</span> <span style=''>for</span> <span style=''>normal</span> <span style=''>data)</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graphs</span> <span style=''>(DAGs)</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>faithfully</span> <span style=''>explain</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independencies</span> <span style=''>and</span> <span style=''>derive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>enumerate</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>map</span> <span style=''>out</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style=''>faithful</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>pairwise</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.4146341463414634);'>independence</span> <span style='background-color:rgba(0, 255, 0, 0.4761904761904762);'>relations</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>show</span> <span style=''>the</span> <span style=''>extent</span> <span style=''>to</span> <span style=''>which</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>without</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.4146341463414634);'>independence</span> <span style=''>tests</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Highly</span> <span style=''>Accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>of</span> <span style=''>Jobs</span> <span style=''>Runtime</span> <span style=''>Classes</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Separating</span> <span style=''>the</span> <span style=''>short</span> <span style=''>jobs</span> <span style=''>from</span> <span style=''>the</span> <span style=''>long</span> <span style=''>is</span> <span style=''>a</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scheduling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>method</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>runtimes</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>the</span> <span style=''>jobs</span> <span style=''>to</span> <span style=''>enable</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>the</span> <span style=''>runtimes</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overlapping</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>train</span> <span style=''>a</span> <span style=''>CART</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>threshold</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separates</span> <span style=''>the</span> <span style=''>short</span> <span style=''>jobs</span> <span style=''>from</span> <span style=''>the</span> <span style=''>long</span> <span style=''>jobs</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>during</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style=''>maximize</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>accuracy</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>indicate</span> <span style=''>overall</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>90</span> <span style=''>for</span> <span style=''>the</span> <span style=''>data</span> <span style=''>set</span> <span style=''>used</span> <span style=''>in</span> <span style=''>our</span> <span style=''>study</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitivity</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23483226266952176)
# 	representations (0.0960028551034975)
# 	knowledge (0.12776588151320487)
# 	representation (0.13561741613133477)
# 	architecture (0.09350463954318344)
# 	segmentation (0.0728051391862955)
# 	detection (0.12276945039257674)
# 	different (0.2648108493932905)
# 	convolutional (0.1363311920057102)
# 	recognition (0.14061384725196288)
#
# Some Statistics words are:
# 	stochastic (0.12762762762762764)
# 	estimation (0.16566566566566568)
# 	variables (0.14014014014014015)
# 	theoretical (0.15265265265265265)
# 	statistical (0.15415415415415415)
# 	inference (0.1891891891891892)
# 	distribution (0.1896896896896897)
# 	algorithm (0.4059059059059059)
# 	dimensional (0.1906906906906907)
# 	regression (0.1856856856856857)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1b6791d1-edac-4386-a588-031853b7da70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b6791d1-edac-4386-a588-031853b7da70")) {                    Plotly.newPlot(                        "1b6791d1-edac-4386-a588-031853b7da70",                        [{"x":["extensive","effectiveness","applications","especially","classification","resemblance","processing","processed","practitioners","empirical","approximating","perspective","parameter","literature","algorithms","corresponds","projections","particular","essentially","procedure","clustering","regression","approximates","effective","consistent","depending","nonlinear","approximate","corresponding","solutions","selecting","discussed","important","classified","understand","limitation","generalization","improving","approaches","different","following","community","comparing","techniques","appropriate","programming","inference","principles","balancing","difficulty","detection","applicability","intractable","connected","likelihood","structured","computationally","activation","performance","algorithm","electrical","generalized","anomalous","relaxation","complexity","infeasible","conditions","statistic","demonstrate","surveillance","posteriori","submodularity","statistical","connection","monitoring","computational","determining","numerical","observations","apprenticeship","comparison","trajectories","posterior","represent","reinforcement","potential","distinguished","implementations","manageable","optimization","objective","quadratic","estimation","demonstrated","framework","dependence","establish","preference","assumptions","generally","initialization","heuristics","encourages","outperforms","acquiring","combinatorial","construct","efficient","constraint","connections","prediction","constrained","conventional","constraints","requiring","empirically","expressive","assignments","exponential","establishing","encodings","polynomial","functions","preliminary","regarding","variables","characterization","propositional","satisfiability","computable","resolution","addresses","convolutional","interesting","representation","benchmarks","developing","capability","structure","configurations","automatically","classical","convolution","discriminative","properties","classifiers","facilitates","contextual","iterative","approximation","accomplish","structural","specification","sequential","capitalizes","institutional","resonance","similarity","segmented","automatic","performed","consuming","architecture","measurements","complimentary","validation","experiments","architectures","osteoporosis","segmentation","exceeding","precision","segmentations","management","volumetric","factorization","recommender","knowledge","extracted","technique","extracting","extraction","incorporate","illustrate","recommendation","available","interactions","expressed","predicted","analyzing","challenging","employing","incorporating","hellinger","relations","explicitly","describing","increasingly","information","experimental","demonstrably","surprisingly","integrate","extending","forgetting","generalize","frequencies","vocabulary","cognitive","interaction","reversing","replicate","investigation","mechanisms","acquisition","attention","presentation","sensitivity","cognitively","processes","hierarchical","exemplars","behaviors","reinforce","generalizing","motivation","transform","including","montezumas","environment","difficult","exploration","uncertainty","inspiration","providing","arbitrary","intrinsic","significantly","specifically","biological","similarities","computation","comparative","alignment","identification","euclidean","frequency","differences","dependent","dimensional","alternatives","usefulness","coefficients","p ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	remainder
# 	sufficiency
# 	acyclicity
# 	overparameterized
# 	horizontally
# 	randomforest
# 	transelliptical
# 	chemoinformatics
# 	extraneous
# 	statisticians
# 	temperatures
# 	tempering
# 	cancerous
# 	warranted
# 	dimensionalities
# 	heteroskedastic
# 	quantiles
# 	impression
# 	sacrifice
# 	factorize
# Some words which never appear in Statistics papers:
# 	apprenticeship
# 	propositional
# 	satisfiability
# 	capitalizes
# 	institutional
# 	osteoporosis
# 	demonstrably
# 	montezumas
# 	categorization
# 	saturating
# 	formations
# 	depressed
# 	statement
# 	harvesting
# 	extractors
# 	translational
# 	navigation
# 	hypernymy
# 	stratification
# 	constituents

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0662619200932145e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
